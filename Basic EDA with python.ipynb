# %% [markdown]
# # **EXPLORE MACHINE LEARNING USING PYTHON**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# %matplotlib inline

# %%
df = pd.read_csv("HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# ## **1) To check whether the dataset can be used as-is**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df.isna().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
# printing column name where infinity is present
df.replace([-np.inf, np.inf], np.nan, inplace = True)

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df["Department"].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
#encoding
mod_df = df
l = mod_df.columns.tolist()
for i in l:
  df1 = []
  req = list(set((mod_df[i].tolist())))
  length = [i for i in range(len(list(set((mod_df[i].tolist())))))]
  res = {}
  for key in req:
    for value in length:
      res[key] = value
      length.remove(value)
      break
  for j in mod_df[i]:
    if type(j) == str:
      required = res[j]
      df1.append(required)
  if len(df1)>0:
    mod_df[i] = df1
  df1 = []

# %%
mod_df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# **The data didn't have any null or nan values, however it required encoding as department and salary were strings, which are then encoded into 'int'**

# %% [markdown]
# ## **2) Relationship between satisifaction level and Working hours of the employee, who left the organization**

# %%
left = mod_df[mod_df.left != 0]
len(left)
# Out:
# 3571

# %%
plt.title("Relation b/w satisifaction level and the working hours")
plt.xlabel("Working hours")
plt.ylabel("Satisfaction level")
plt.scatter(left.average_montly_hours, left.satisfaction_level, color = 'cyan')

# %%
#checking correlation coefficient for the type of relation b/w satisifaction level and the working hours

corr = np.corrcoef(left.average_montly_hours, left.satisfaction_level)
corr
# Out:
# array([[ 1.        , -0.08411746],
#        [-0.08411746,  1.        ]])

# %% [markdown]
# **From the graph and calculated correlation co-efficient, it is clearly seen that the relationship b/w average working hours and the satisifaction level is negative, and they are weakly related as the magnitude is close to zero**

# %% [markdown]
# ## **3)Effect of satisifaction level, department, promotion in last five years and salary level of employees, who have left the organization**

# %%
req = mod_df.drop(['last_evaluation',
 'number_project',
 'average_montly_hours',
 'time_spend_company',
 'Work_accident'], axis = 1)

# %%
req.corr()
# Out:
#                        satisfaction_level      left  promotion_last_5years  \
# satisfaction_level               1.000000 -0.388375               0.025605
# left                            -0.388375  1.000000              -0.061788
# promotion_last_5years            0.025605 -0.061788               1.000000
# Department                       0.008482  0.001907              -0.057138
# salary                          -0.050022  0.157898              -0.098119
#
#                        Department    salary
# satisfaction_level       0.008482 -0.050022
# left                     0.001907  0.157898
# promotion_last_5years   -0.057138 -0.098119
# Department               1.000000  0.050638
# salary                   0.050638  1.000000

# %%
import seaborn as sb

dataplot = sb.heatmap(req.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

X = mod_df.drop('left', axis = 1)  #independent columns
y = mod_df.left    #target column i.e 'left'
#apply SelectKBest class to extract top 8 best features
bestfeatures = SelectKBest(score_func=chi2, k=8)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(8,'Score'))
# Out:
#                    Specs       Score
# 3   average_montly_hours  945.588933
# 5          Work_accident  306.737710
# 0     satisfaction_level  228.193183
# 4     time_spend_company  191.708547
# 8                 salary  108.030567
# 6  promotion_last_5years   56.044865
# 2         number_project    3.390205
# 7             Department    0.061952

# %%
len(mod_df.columns.to_list())
# Out:
# 10

# %%
mod_df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
mod_df.columns.to_list()
# Out:
# ['satisfaction_level',
#  'last_evaluation',
#  'number_project',
#  'average_montly_hours',
#  'time_spend_company',
#  'Work_accident',
#  'left',
#  'promotion_last_5years',
#  'Department',
#  'salary']

# %%
x = mod_df[['satisfaction_level',
 'average_montly_hours',
 'time_spend_company',
 'Work_accident',
 'salary']]
y = mod_df['left']

# %%
x
# Out:
#        satisfaction_level  average_montly_hours  time_spend_company  \
# 0                    0.38                   157                   3
# 1                    0.80                   262                   6
# 2                    0.11                   272                   4
# 3                    0.72                   223                   5
# 4                    0.37                   159                   3
# ...                   ...                   ...                 ...
# 14994                0.40                   151                   3
# 14995                0.37                   160                   3
# 14996                0.37                   143                   3
# 14997                0.11                   280                   4
# 14998                0.37                   158                   3
#
#        Work_accident  salary
# 0                  0       2
# 1                  0       1
# 2                  0       1
# 3                  0       2
# ...

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x,y,test_size = 0.25,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

X_train = StandardScaler().fit_transform(X_train)
X_test = StandardScaler().fit_transform(X_test)

# %% [markdown]
# ## **4) Machine Learning models to predict the exit of employees**

# %% [markdown]
# ## **Decision Tree**

# %%
#decision tree using gini
from sklearn.tree import DecisionTreeClassifier


clf = DecisionTreeClassifier(criterion='gini',max_depth = 6, random_state=0)
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, random_state=0)

# %%
#prediction of the decision tree for test data
Y_pred = clf.predict(X_test)
Y_pred
# Out:
# array([1, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
#accuracy score of the decision tree
from sklearn.metrics import accuracy_score
print('Model accuracy score with criterion entropy: {0:.4f}'. format(accuracy_score(Y_test, Y_pred)))
# Out:
# Model accuracy score with criterion entropy: 0.9483

# %%
#checking the decision tree's accuracy in the training data
Y_train_pred = clf.predict(X_train)

#accuracy score of the decision tree for the train data
print('Model accuracy score with criterion entropy: {0:.4f}'. format(accuracy_score(Y_train, Y_train_pred)))
# Out:
# Model accuracy score with criterion entropy: 0.9712

# %%
#comparing the model's train and test scores

print('Training set score: {:.4f}'.format(clf.score(X_train, Y_train)))
print('Test set score: {:.4f}'.format(clf.score(X_test, Y_test)))
# Out:
# Training set score: 0.9712
# Test set score: 0.9483

# %%
#confusion matrix for the test

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(Y_test, Y_pred)
print('Confusion matrix\n\n', cm)

cm_display = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ['Not Left', 'Left'])

cm_display.plot()
plt.show()
# Out:
# Confusion matrix
#
#  [[2837   44]
#  [ 150  719]]

# %%
#Accuracy check using classification report

from sklearn.metrics import classification_report

print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      2881
#            1       0.94      0.83      0.88       869
#
#     accuracy                           0.95      3750
#    macro avg       0.95      0.91      0.92      3750
# weighted avg       0.95      0.95      0.95      3750

# %%
#importing packages for plotting the tree
from sklearn import tree
import graphviz

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=X_train[1, :],  
                   class_names=['1','2','3','4','5','6','7','8','9',],
                   filled=True)

# %% [markdown]
# ## **SVM**

# %%
# implementing SVM for the same
from sklearn.svm import SVC

x_train = X_train
x_test = X_test
y_train = Y_train
y_test = Y_test

# %%
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(x_train, y_train)

print(classifier.score(x_train,y_train))
print(classifier.score(x_test,y_test))
# Out:
# 0.9412392212641124
# 0.9413333333333334

# %%
y_pred = classifier.predict(X_test)

# %%
print("Training score: ", accuracy_score(y_train, classifier.predict(x_train)))
print("Testing score: ", accuracy_score(y_test, y_pred))
# Out:
# Training score:  0.9412392212641124
# Testing score:  0.9413333333333334

# %%
print("Training score: ", classifier.score(x_train, y_train))
print("Testing score: ", classifier.score(x_test, y_test))
# Out:
# Training score:  0.9412392212641124
# Testing score:  0.9413333333333334

# %%
cm = confusion_matrix(y_test, y_pred)
print('Confusion matrix\n\n', cm)

cm_display = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ['Not Left', 'Left'])

cm_display.plot()
plt.show()
# Out:
# Confusion matrix
#
#  [[2763  118]
#  [ 102  767]]

# %%
#Accuracy check using classification report

from sklearn.metrics import classification_report

print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      2881
#            1       0.94      0.83      0.88       869
#
#     accuracy                           0.95      3750
#    macro avg       0.95      0.91      0.92      3750
# weighted avg       0.95      0.95      0.95      3750

# %% [markdown]
# ## **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier
classifier2 = RandomForestClassifier(n_estimators = 10, criterion = 'gini')
classifier2.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
y_pred2 = classifier2.predict(x_test)

# %%
y_train_pred2 = classifier2.predict(x_train)

# %%
#Training and Testing scores
print("Training score: ", classifier2.score(x_train, y_train))
print("Testing score: ", classifier2.score(x_test, y_test))
# Out:
# Training score:  0.9950217797137524
# Testing score:  0.9613333333333334

# %%
print("Training score: ", accuracy_score(y_train, classifier2.predict(x_train)))
print("Testing score: ", accuracy_score(y_test, y_pred2))
# Out:
# Training score:  0.9950217797137524
# Testing score:  0.9613333333333334

# %%
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      2881
#            1       0.96      0.87      0.91       869
#
#     accuracy                           0.96      3750
#    macro avg       0.96      0.93      0.94      3750
# weighted avg       0.96      0.96      0.96      3750
